# %%
import pandas as pd

# %%
data = pd.read_csv('Iris_data.csv')

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Class
# 0             5.1          3.5           1.4          0.2      1
# 1             4.9          3.0           1.4          0.2      1
# 2             4.7          3.2           1.3          0.2      1
# 3             4.6          3.1           1.5          0.2      1
# 4             5.4          3.9           1.7          0.4      1
# 5             4.6          3.4           1.4          0.3      1
# 6             5.0          3.4           1.5          0.2      1
# 7             4.4          2.9           1.4          0.2      1
# 8             4.9          3.1           1.5          0.1      1
# 9             4.8          3.4           1.6          0.2      1
# 10            4.3          3.0           1.1          0.1      1
# 11            5.8          4.0           1.2          0.2      1
# 12            5.7          4.4           1.5          0.4      1
# ...

# %%
myData = pd.read_excel('Data.xlsx','Diet')
#myData = pd.read_excel('Data.xlsx',1)

# %%
myData
# Out:
#    Subject  Before  After
# 0        1      88     85
# 1        2      97     88
# 2        3     112    100
# 3        4      91     86
# 4        5      85     79
# 5        6      95     89
# 6        7      98     90
# 7        8     112    100
# 8        9     133    126
# 9       10     141    129

# %%
data_online = pd.read_csv('https://github.com/mohan-mj/Regression_Analysis/blob/master/datasets/Mult_Reg_Yield.csv')
data_online
